# %% [markdown]
# # Fichier de data exploration

# %%
import pandas as pd
df = pd.read_csv("../raw_data/superheroes_data.csv", index_col="id")

# %% [markdown]
# Visualisation

# %%
df.head()
# Out:
#            name  intelligence  strength  speed  durability  power  combat  \
# id
# 1        A-Bomb          38.0     100.0   17.0        80.0   24.0    64.0
# 2    Abe Sapien          88.0      28.0   35.0        65.0  100.0    85.0
# 3      Abin Sur          50.0      90.0   53.0        64.0   99.0    65.0
# 4   Abomination          63.0      80.0   53.0        90.0   62.0    95.0
# 5       Abraxas          88.0      63.0   83.0       100.0  100.0    55.0
#
#                  full-name            alter-egos  \
# id
# 1   Richard Milhouse Jones  No alter egos found.
# 2           Abraham Sapien  No alter egos found.
# 3                      NaN  No alter egos found.
# 4             Emil Blonsky  No alter egos found.
# 5                  Abraxas  No alter egos found.
#
#                                               aliases  ...               race  \
# id                                                     ...
# ...

# %% [markdown]
# Types des colonnes

# %%
df.dtypes
# Out:
# name                  object
# intelligence         float64
# strength             float64
# speed                float64
# durability           float64
# power                float64
# combat               float64
# full-name             object
# alter-egos            object
# aliases               object
# place-of-birth        object
# first-appearance      object
# publisher             object
# alignment             object
# gender                object
# race                  object
# height                object
# weight                object
# eye-color             object
# hair-color            object
# occupation            object
# base                  object
# group-affiliation     object
# relatives             object
# url                   object
# dtype: object

# %% [markdown]
# Nombre de champs non renseignés par colonne

# %%
df.isna().sum()
# Out:
# name                   0
# intelligence         165
# strength             102
# speed                165
# durability           165
# power                165
# combat               165
# full-name            101
# alter-egos             0
# aliases                0
# place-of-birth         0
# first-appearance       0
# publisher             15
# alignment              0
# gender                 0
# race                 302
# height                 0
# weight                 0
# eye-color              0
# hair-color             0
# occupation             0
# base                   0
# group-affiliation      0
# relatives              0
# url                    0
# dtype: int64

# %% [markdown]
# Visualisation des lignes ou le champ ```intelligence``` est NaN

# %%
df[df["intelligence"].isna()]
# Out:
#                  name  intelligence  strength  speed  durability  power  \
# id
# 9            Agent 13           NaN      46.0    NaN         NaN    NaN
# 16       Alex Woolsly           NaN      37.0    NaN         NaN    NaN
# 19   Allan Quatermain           NaN       NaN    NaN         NaN    NaN
# 21               Ammo           NaN       NaN    NaN         NaN    NaN
# 22     Ando Masahashi           NaN       NaN    NaN         NaN    NaN
# ..                ...           ...       ...    ...         ...    ...
# 710         Weapon XI           NaN       NaN    NaN         NaN    NaN
# 712       White Queen           NaN       NaN    NaN         NaN    NaN
# 715           Wiz Kid           NaN       NaN    NaN         NaN    NaN
# 721            Wondra           NaN       NaN    NaN         NaN    NaN
# 725       Yellow Claw           NaN       NaN    NaN         NaN    NaN
#
#      combat         full-name            alter-egos  \
# id
# ...

# %% [markdown]
# ### Vérification des unités de taille et de poids

# %%
df["height(cm)"] = df["height"].map(lambda x: x[-1])

# %%
df = df.drop(columns="height(cm)", axis=1)

# %%
text = df["height"][400]
print(text)
# Out:
# ["5'9", '175 cm']

# %%
type(text)
# Out:
# str

# %%
value = text.split("'")[-2].split(" ")[0]
unit = text.split("'")[-2].split(" ")[1]
print(f"Le héros mesure {value} {unit}")
# Out:
# Le héros mesure 175 cm

# %%
df["unit_height"] = df["height"].map(lambda x: x.split("'")[-2].split(" ")[1])

# %%
df["unit_height"].value_counts()
# Out:
# unit_height
# cm          723
# meters        7
# Heights,      1
# Name: count, dtype: int64

# %%
df[df["unit_height"] == "Heights,"]
# Out:
#        name  intelligence  strength  speed  durability  power  combat  \
# id
# 198  Dagger          63.0      10.0   35.0        42.0   52.0    70.0
#
#        full-name            alter-egos         aliases  ...  \
# id                                                      ...
# 198  Tandy Bowen  No alter egos found.  ['Lady Light']  ...
#
#                        height               weight eye-color hair-color  \
# id
# 198  ['Shaker Heights, Ohio']  ['116 lb', '52 kg']      Blue      Blond
#
#     occupation                                           base  \
# id
# 198  Vigilante  Holy Ghost Church, 42nd Street, New York City
#
#                                      group-affiliation  \
# id
# 198  Cloak and Dagger, Defenders, League of Losers,...
#
#                                              relatives  \
# id
# 198  Melissa Bowen (mother), unnamed father, Philli...
#
#                                                    url unit_height
# id
# ...

# %%
df["unit_weight"] = df["weight"].map(lambda x: x.split("'")[-2].split(" ")[1])

# %%
df["unit_weight"].value_counts()
# Out:
# unit_weight
# kg      724
# tons      7
# Name: count, dtype: int64

# %%
df[df["unit_weight"] == "tons"]
# Out:
#               name  intelligence  strength  speed  durability  power  combat  \
# id
# 256  Fin Fang Foom          50.0      81.0   23.0       100.0   75.0    70.0
# 273       Galactus         100.0     100.0   83.0       100.0  100.0    50.0
# 287       Godzilla          44.0     100.0   54.0       100.0  100.0    20.0
# 303          Groot          75.0      85.0   33.0        70.0  100.0    64.0
# 347    Iron Monger          88.0      63.0   25.0        90.0   57.0    56.0
# 389      King Kong          56.0     100.0   71.0        75.0   47.0    75.0
# 681    Utgard-Loki          50.0      80.0   23.0        84.0   85.0    64.0
#
#          full-name            alter-egos  \
# id
# 256            NaN  No alter egos found.
# 273          Galan  No alter egos found.
# 287         Gojira  No alter egos found.
# 303          Groot  No alter egos found.
# 347  Obadiah Stane  No alter egos found.
# 389      King Kong  No alter egos found.
# 681            NaN  No alter egos found.
#
# ...

# %%
df[df["name"] == "Thanos"]
# Out:
#        name  intelligence  strength  speed  durability  power  combat  \
# id
# 655  Thanos         100.0     100.0   33.0       100.0  100.0    80.0
#
#     full-name            alter-egos  \
# id
# 655    Thanos  No alter egos found.
#
#                                                aliases  ...  \
# id                                                      ...
# 655  ['The Mad Titan', 'Masterlord', 'The Overmaste...  ...
#
#                    weight eye-color hair-color                     occupation  \
# id
# 655  ['985 lb', '443 kg']       Red    No Hair  Conqueror, worshiper of Death
#
#                                      base  \
# id
# 655  Mobile, formerly Sanctuary II, Titan
#
#                                      group-affiliation  \
# id
# 655  Zodiac (ally); formerly Infinity Watch, Defenders
#
#                                              relatives  \
# id
# 655  A'Lars (father): Sui-San (mother, deceased; Er...
#
# ...

# %%
type(df["aliases"][2])
# Out:
# str

# %%
df[~df["unit_height"].isin(["cm", "meters"])].index
# Out:
# Index([32, 122, 198, 284, 287, 389, 681, 728], dtype='int64', name='id')

# %%
df["aliases"]
# Out:
# id
# 1                                         ['Rick Jones']
# 2      ['Langdon Everett Caul', 'Abraham Sapien', 'La...
# 3                                             ['Lagzia']
# 4                     ['Agent R-7', 'Ravager of Worlds']
# 5                                                  ['-']
#                              ...
# 727                                                ['-']
# 728                                        ['Aurgelmir']
# 729                                                ['-']
# 730                                                ['-']
# 731                                                ['-']
# Name: aliases, Length: 731, dtype: object

# %%
df["relatives"][311]
# Out:
# 'Oscar Summers (adoptive paternal distant ancestor, deceased), Daniel Summers (paternal distant ancestor, deceased), Amanda Mueller (Black Womb) (paternal distant ancestor), unnamed paternal great-grandfather, deceased, Gloria Dayne (Fontanelle) (paternal distant ancestor), Philip Summers (paternal grandfather), Deborah Summers (paternal grandmother), Christopher Summers (Corsair) (father, deceased), Katherine Summers (mother, deceased), Andrew Blanding (adoptive father), Joanna Blanding (adoptive mother), Scott Summers (Cyclops) (brother), Gabriel Summers (Vulcan) (brother, deceased), Ahmet Abdol (Living Monolith) ("brother" via X-Gene transfer), Haley Blanding (adoptive sister), Todd Blanding (adoptive brother, deceased), Madelyne Pryor-Summers (Red Queen) (sister-in-law/clone of second sister-in-law, deceased), Jean Grey-Summers (Phoenix) (sister-in-law, deceased), Cal\'syee Neramani (Deathbird) (sister-in-law), Nathan Summers (Cable) (nephew), Adam Neramani (X-Treme) (nephew, all
# ...

# %%
df["height(cm)"]
# Out:
# id
# 1        203
# 2        191
# 3        185
# 4        203
# 5          0
#        ...
# 727      165
# 728    304.8
# 729       66
# 730      170
# 731      185
# Name: height(cm), Length: 731, dtype: object

# %%
df.dtypes
# Out:
# name                  object
# intelligence         float64
# strength             float64
# speed                float64
# durability           float64
# power                float64
# combat               float64
# full-name             object
# alter-egos            object
# aliases               object
# place-of-birth        object
# first-appearance      object
# publisher             object
# alignment             object
# gender                object
# race                  object
# height                object
# weight                object
# eye-color             object
# hair-color            object
# occupation            object
# base                  object
# group-affiliation     object
# relatives             object
# url                   object
# unit_height           object
# unit_weight           object
# height(cm)            object
# dtype: object
